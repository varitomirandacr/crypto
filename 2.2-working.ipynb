# %%
p = 7422236843002619998657542152935407597465626963556444983366482781089760760914403641211700959458736191688739694068306773186013683526913015038631710959988771
q = 7422236843002619998657542152935407597465626963556444983366482781089760759017266051147512413638949173306397011800331344424158682304439958652982994939276427
print(p*q)
# Out:
# 

# %%
import gmpy2

#N = 
N = ...
#N = 
#N = ...

def fermat_factor(n):
    assert n % 2 != 0

    a = gmpy2.isqrt(n)
    b2 = gmpy2.square(a) - n

    while not gmpy2.is_square(b2):
        a += 1
        b2 = gmpy2.square(a) - n

    p = a + gmpy2.isqrt(b2)
    q = a - gmpy2.isqrt(b2)

    return int(p), int(q)

if __name__ == "__main__":
    (p, q) = fermat_factor(N)

    print("p = {}".format(p))
    print("q = {}".format(q))
# Out:
# p = 
# q = 

# %%
def isqrt(n, root='ok'):
	x=n
	y=(x+n//x)//2
	while(y<x):
		x=y
		print("X: ", x)
		y=(x+n//x)//2
		print("Y: ", y)
	return x

def fermat(n):
	t0=isqrt(n, root="el primero")+1
	print("T0: ", t0)
	counter=0
	t=t0+counter
	temp=isqrt((t*t)-n, root="to temp")
	while((temp*temp)!=((t*t)-n)):
		counter+=1
		t=t0+counter
		temp=isqrt((t*t)-n, root="inside while")
	s=temp
	p=t+s
	q=t-s
	return p,q

print("Enter the number to factor of form (p*q):	")
#n=int(hex(),16)
#n = ...
#n = 
#n = ...
n = 20503
p,q=fermat(n)
print("Your first number   : ",int(p))
print("Your Second number  : ",int(q))
p = 10
q = 20

# %%
xbn = math.sqrt(267)
print(int(xbn)-xbn == 0)
# Out:
# False

# %%
import math

#print(ceiling(math.sqrt(23449)))
#print(math.pow(144,2))

#n = 23449
n = 20503
found = False
x = math.ceil(math.sqrt(n))
print("First X: ", x)
print("WHILE.................")
while(found == False):
    x_ = (x**2)-n
    sx_ = math.sqrt(x_)
    print(sx_)


    if (int(sx_)-sx_ == 0):
        found = True
        print("X: ", x)
        print("sx_**2: ", sx_**2)
        print("(x+sx_)*(x-sx_): ", (x+sx_)*(x-sx_))

        _p = int((x-sx_))
        _2p = 2*_p
        _q = int(x+sx_)
        print("P: ", _p)
        print("2p: ", _2p)
        print("q: ", _q)
        print("2p - q: ", _2p - _q)
    else: x+=1
print("WHILE.................")
# Out:
# First X:  144
# WHILE.................
# 15.264337522473747
# WHILE.................
# 22.847319317591726
# WHILE.................
# 28.513154858766505
# WHILE.................
# 33.25657829663178
# WHILE.................
# 37.429934544425805
# WHILE.................
# 41.20679555607303
# WHILE.................
# 44.68780594300866
# WHILE.................
# 47.93745925682754
# WHILE.................
# 51.0
# X:  152
# sx_**2:  2601.0
# (x+sx_)*(x-sx_):  20503.0
# P:  101
# 2p:  202
# q:  203
# 2p - q:  -1

# %%
#pip install sympy
from sympy import sqrt, log, ceiling, Integer

def is_square(n):
    return type(sqrt(n)) == Integer

def fermat_factor(n):
    num_digits = int(log(n, 10).evalf() + 1)
    print("Num Digits: ", num_digits)
    a = ceiling( sqrt(n).evalf(num_digits) )
    print("A: ", a)
    counter = 0
    sqrt_ = sqrt(n)
    print("SQRT: ", sqrt_)
    while not is_square(a*a - n):
        a += 1
        counter += 1

    b = sqrt(a*a - n)
    print("B: ", b)
    return(a+b, a-b, counter)

#p = 314159200000000028138418196395985880850000485810513
#q = 314159200000000028138415196395985880850000485810479
#ny = ...
ny = ...
print( fermat_factor(ny) )
#print( fermat_factor(p*q) )
# Out:
# Num Digits:  617
# A:  
# SQRT:  sqrt(...)
# B:  42
# (, , 0)

# %%
# RANDOM TEST

from sympy import sqrt as sqrt3, log, ceiling, Integer, Pow as pow3

n3 = ...
#e3 = ...

x = sqrt3(n3)
print("SQ3 de x: ", x)
print(n3//x)
found = False
while(found == False):
    x_ = pow3(x, 2)-n3
    print("X_ **2 -n3", x_)
    #sx_ = math.sqrt(x_)
    sx_ = sqrt3(x_)
    print("SX_: ", sx_)
    if (sx_.compare(sx_) == 0): 
        found = True
        _p = (x-sx_)
        _2p = 2*_p
        _q = (x+sx_)
        print("inside")
    else: x+=1

# %%
# WORKING CUSTOM
import math
import gmpy2 
from decimal import Decimal

t4, t3, t2, t1 = "\t\t\t\t", "\t\t\t", "\t\t", "\t"

#n = 23449
#n = 20503
#n6 = gmpy2.mpz(...)
n6 = gmpy2.mpz(...)
print("N:",t4, n6)
found = False
x = gmpy2.isqrt(n6)
print("First X:",t3, int(x))
print("WHILE.................START")
c = 0
while(not found):
    c+=1
    #if (c % 10000000 == 0):
    #    print("C: ", c)

    b = (x**2)-n6
    if b > 0:
        #print("inside")
        sx_ = gmpy2.isqrt(b)
        #print("gmpy2.sqrt(b):",t1, sx_)

    #print("SX_:", sx_)        
    #print("(x**2)-n:",t3, b)    
    #print("(x**2):",t3, (x**2), n)
    
    if (gmpy2.is_square(b)): #int(sx_)-sx_ == 0):
        print("ENTERED FINAL")
        found = True        
        _p = (x+sx_)
        _2p = 2*_p
        _q = (x-sx_)
        #print("X: ",t4, x)
        #print("sx_**2: ",t3, int(sx_**2))
        #print("(x+sx_)*(x-sx_): ",t2, int((x+sx_)*(x-sx_)))
        #print("(x-sx_) | P: ",t3, _p)
        #print("2p: ",t4, _2p)
        #print("q: ",t4, _q)
        #print("2p - q: ",t3, _2p - _q)
    else: x+=1

print("(x+sx_)*(x-sx_): ",t2, int((x+sx_)*(x-sx_)))
print("q: ",t4, _q)
print("2p: ",t4, _2p)
print("(x-sx_) | P: ",t3, _p)
print("2p - q: ",t3, _2p - _q)
# Out:
# N: 				 ...
# First X: 			 
# WHILE.................START
# ENTERED FINAL
# (x+sx_)*(x-sx_):  		 ...
# q:  				 
# 2p:  				 
# (x-sx_) | P:  			 
# 2p - q:  			 
